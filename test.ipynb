# %%
import pandas as pd

df_maengel = pd.read_csv("data/Wolfsburg_Maengelmeldungen_2.csv")
df_maengel.head()
# Out:
#             user_standort    timestamp_meldung timestamp_letzteBearbeitung  \
# 0        (52.421, 10.795)  2024-11-11 11:53:11         2024-11-11 17:53:11
# 1        (52.421, 10.795)  2024-08-05 10:54:57         2024-08-05 20:54:57
# 2        (52.421, 10.795)  2025-03-03 17:25:59         2025-03-05 15:25:59
# 3  (52.420148, 10.769726)  2024-08-13 13:09:30         2024-08-14 15:09:30
# 4  (52.426669, 10.790072)  2024-08-30 14:20:48         2024-09-01 01:20:48
#
#                                  user_text  \
# 0  Straßenlaterne vor meinem Haus flackert
# 1          Mülleimer im Park ist überfüllt
# 2          Glasscherben auf dem Spielplatz
# 3       Eichenprozessionsspinner gesichtet
# 4       Gulli verstopft, Wasser staut sich
#
#                                  user_kategorie        ki_stelle ki_prio
# 0                            Straßenbeleuchtung       Straßenbau     low
# 1                              Abfallentsorgung   Stadtreinigung     low
# ...
